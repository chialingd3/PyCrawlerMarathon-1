# %%
import requests
r = requests.get('https://www.dcard.tw/_api/forums/job/posts?popular=true')
response = r.text
import json
data = json.loads(response)
print(len(data))
# Out:
# 30

# %%
for d in data:
    print(d['title'])
    print(d['createdAt'])
    print(d['commentCount'])
    print(d['likeCount'])
# Out:
# <請先點我> 工作板＆實習、打工職缺刊登說明
# 2017-01-01T06:27:39.650Z
# 42
# 715
# 大學生畢業不會 Excel、word
# 2020-06-15T05:37:53.912Z
# 211
# 820
# 2020 👩‍💼MA面試心得錄取後👨‍💼 (中信/國泰/中壽/中租-台新) Plus準備指南/簡報/資料分享🎖🏆
# 2020-06-15T18:04:09.673Z
# 38
# 302
# ［爆料公司高調］請生理假被主管這樣對待！！！
# 2020-06-15T06:22:16.992Z
# 44
# 250
# 為什麼決定在畢業前自學 UI / UX？
# 2020-06-15T13:56:45.478Z
# 6
# 30
# 媒設系剛畢業起薪
# 2020-06-15T01:40:20.110Z
# 11
# 24
# 請問這波疫情大家多長的時間找到工作！？
# 2020-06-15T11:08:00.621Z
# 17
# 22
# 應屆畢業生徵才活動分享~
# 2020-06-15T02:28:39.041Z
# 0
# 19
# 兩個銀行Offer的抉擇
# 2020-06-15T03:14:18.139Z
# 22
# 18
# 銀行行員V.S.事務所選擇
# 2020-06-15T10:42:21.766Z
# 37
# 17
# 青年就業領三萬 去年畢業的男生也太衰
# 2020-06-15T10:33:38.115Z
# 30
# 17
# 公司爛不是一天兩天的事
# 2020-06-16T00:20:26.681Z
# 22
# 13
# 現在的工作好難找
# 2020-06-15T07:14:31.880Z
# 16
# 10
# 蝦皮人資背景
# 2020-06-15T12:32:49.887Z
# 4
# 8
# 人資單位
# 2020-06-15T01:51:38.092Z
# 5
# 8
# 慶云（文長）
# 2020-06-16T02:22:18.770Z
# 12
# 7
# 想去屈x氏上班勸世文
# 2020-06-15T18:57:47.008Z
# 3
# 7
# 大家會有這種無力的感覺嗎？
# 2020-06-15T03:18:54.954Z
# 13
# 7
# 台中銀行、中信、台北富邦
# 2020-06-15T00:19:15.108Z
# 23
# 7
# 在補習班工作的日子
# 2020-06-15T16:31:45.423Z
# 4
# 6
# 台積電人資面試
# 2020-06-15T15:16:59.486Z
# 6
# 6
# 今天是警察節！👮‍♂️👮‍♀️
# 2020-06-15T13:37:04.392Z
# 4
# 6
# 面試完會一直檢討自己
# 2020-06-15T13:17:56.493Z
# 3
# 5
# 台積電面試
# 2020-06-15T06:57:54.022Z
# 16
# 5
# 應徵中國信託客服
# 2020-06-15T06:00:47.124Z
# 20
# 5
# 【強力招募！】台北/旅遊新創Tripresso 旅遊咖/旅遊產品企劃工讀生
# 2020-06-15T02:55:14.333Z
# 0
# 5
# 進入職場就像進入比特犬的地盤
# 2020-06-15T00:19:51.840Z
# 1
# 5
# 如果想走數位行銷，讀報表真的是基本功
# 2020-06-16T04:20:18.686Z
# 0
# 4
# 疫情要到何時呢？
# 2020-06-16T02:50:40.930Z
# 4
# 4
# 機械  電機 資工 科系 畢業後工作起薪會差很多嗎？
# 2020-06-16T01:37:48.135Z
# 25
# 4

# %%
commentCount = 0
likeCount = 0
for d in data:
    commentCount += d['commentCount']
    likeCount += d['likeCount']
print(commentCount/len(data),likeCount/len(data))
# Out:
# 21.3 78.53333333333333

# %%
r = requests.get('https://www.dcard.tw/_api/forums/job/posts?popular=false')
response = r.text
data = json.loads(response)
commentCount = 0
likeCount = 0
for d in data:
    commentCount += d['commentCount']
    likeCount += d['likeCount']
print(commentCount/len(data),likeCount/len(data) )
# Out:
# 1.3333333333333333 1.0333333333333334
