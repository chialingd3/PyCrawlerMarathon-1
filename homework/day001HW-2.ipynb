# %%
from urllib.request import urlretrieve
urlretrieve ("https://www.w3.org/TR/PNG/iso_8859-1.txt","./homework.txt")
urlretrieve ("https://www.w3.org/TR/PNG/iso_8859-1.txt","./data/homework.txt")
# Out:
# ('./data/homework.txt', <http.client.HTTPMessage at 0x7f9c20a91450>)

# %%
import os, sys

dirs= os.listdir( './' )

for file in dirs:
    print(file)
# Out:
# notebooks
# jupyterlab-slides.pdf
# Lorenz.ipynb
# TCGA_Data
# markdown_python.md
# data
# lorenz.py
# big.csv
# jupyterlab.md
# .ipynb_checkpoints
# day001HW-2.ipynb
# homework.txt

# %%
with open("homework.txt", "w") as fh:
    f=fh.write("Hello World")
    print(f)

with open("homework.txt", "r") as fh:
    f=fh.read()
    print(f)
# Out:
# 11
# Hello World

# %%
import os, sys
dirs = os.listdir('./')
for file in dirs:
    print(file)
# Out:
# notebooks
# jupyterlab-slides.pdf
# Lorenz.ipynb
# TCGA_Data
# markdown_python.md
# data
# lorenz.py
# big.csv
# jupyterlab.md
# .ipynb_checkpoints
# day001HW-2.ipynb
# homework.txt

# %%
import chardet

f = open("homework.txt", "rb")
data = f.read()
print(chardet.detect(data))
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}
